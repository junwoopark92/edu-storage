# %%
import tensorflow as tf
import pandas as pd
import numpy as np

import matplotlib.colors as clrs
import matplotlib.pyplot as plt
import matplotlib.animation as animation

from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D

# %matplotlib nbagg

# %% [markdown]
# ### 0. Sample data 생성
# f = -x1 - x2 를 dicision boundary로 갖는 데이터를 생성한다

# %%
def data2d_create(center,num,r = 3):
    data = np.random.randn(num,2)*r
    data[:,0] = data[:,0] + center[0]
    data[:,1] = data[:,1] + center[1]
    return data

# %%
num_of_data = 100
class1=data2d_create((0,0),num_of_data)
class2=data2d_create((15,15),num_of_data)
class1=np.concatenate([class1,np.ones((num_of_data,1))],1)
class2=np.concatenate([class2,-np.ones((num_of_data,1))],1)
print(class1.shape,class2.shape)
# Out:
# (100, 3) (100, 3)

# %%
#class1[0][0] =-8000
#class1[0][1] = 1000 # -Y\*y vs Max(0,-Y\*y)

# %%
class1[:5]
# Out:
# array([[ 0.04201954,  2.96247898,  1.        ],
#        [-2.16927281,  3.00894669,  1.        ],
#        [-1.54692071, -2.95186667,  1.        ],
#        [-0.42570067, -1.28895476,  1.        ],
#        [-1.02617367, -0.02014906,  1.        ]])

# %%
class2[:5]
# Out:
# array([[ 13.12237254,  11.28754749,  -1.        ],
#        [ 13.27065981,  16.17077491,  -1.        ],
#        [ 15.90334811,  13.46669259,  -1.        ],
#        [ 13.37565843,  15.98682499,  -1.        ],
#        [ 17.74991118,  11.96596256,  -1.        ]])

# %%
fig, [[ax1,ax2],[ax3,ax4],[_,_]] = plt.subplots(nrows=3,ncols=2,figsize=(10,15),dpi=80)

ax1.set_ylim(-20,20)
ax1.set_xlim(-20,20)
ax1.set_xlabel("x1")
ax1.set_ylabel("x2")

x = np.linspace(-8000,8000,100)
ax1.plot(x,-x,label = 'f',c='red')
ax1.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3,
           ncol=2, mode="expand", borderaxespad=0.)
ax1.scatter(class1[:,0],class1[:,1],c='orange',)
ax1.scatter(class2[:,0],class2[:,1],c='blue')

ax2.axis('off')
_.set_xlabel("margin")
_.set_ylabel("error")

margin = np.linspace(-10,10,100)
_.set_ylim(-5,5)
_.set_xlim(-5,5)
_.plot(margin,-margin,label='-Y*y')
_.plot(margin,np.maximum(0,-margin),label='perceptron loss')
_.plot(margin,np.maximum(0,1-margin),label='hinge loss')
_.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3,
           ncol=2, mode="expand", borderaxespad=0.)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
train = np.concatenate([class1,class2],0)
np.random.shuffle(train)
train[:5]
# Out:
# array([[ 16.00066247,  13.13000122,  -1.        ],
#        [ 16.50392284,  15.35356865,  -1.        ],
#        [ 16.88571414,  14.82332412,  -1.        ],
#        [ -1.54692071,  -2.95186667,   1.        ],
#        [  1.1375396 ,  -1.41897788,   1.        ]])

# %%
train_X = train[:,:2]
train_Y = train[:,2]

# %% [markdown]
# ### hyper parameter 입력

# %%
def binary_activation(x):
    cond = tf.less(x, tf.zeros(tf.shape(x)))
    out = tf.where(cond, -tf.ones(tf.shape(x)), tf.ones(tf.shape(x)))
    return out

# %%
learning_rate = 1
epoch = 400

# %% [markdown]
# ### tesorflow symbol 선언

# %%
X = tf.placeholder(tf.float32,shape =[None,2])
Y = tf.placeholder(tf.float32,shape =[None,1])

W = tf.Variable([[1.0],
                 [-1.0]])
b = tf.Variable(tf.zeros([1]))

# %% [markdown]
# ### symbol 관계정의

# %%
f = tf.add(tf.matmul(X,W),b)
accuracy = tf.reduce_mean(tf.cast(tf.equal(binary_activation(f),Y),tf.float32))

#error = tf.reduce_mean(tf.maximum(0.0,1-Y*f)) # hinge loss
error = tf.reduce_mean(tf.maximum(0.0,-Y*f)) # perceptron loss
#error = tf.reduce_mean(-Y*f) # not use max
#error = 1/2*tf.square(tf.norm(W))+tf.reduce_mean(tf.maximum(0.0,1-Y*f))

optimizer = tf.train.GradientDescentOptimizer(learning_rate=learning_rate)
train_op = optimizer.minimize(error)

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())
sess.run(tf.norm(W))
sess.run(1/2*tf.norm(W)*tf.norm(W)+tf.reduce_mean(tf.maximum(0.0,1-Y*f)),feed_dict={X: train_X, Y: train_Y.reshape(len(train_Y),1)})
# Out:
# 3.1539245

# %% [markdown]
# ### seesion 정의 및 실행

# %%
w_list = []
b_list = []
error_list = []
acc_list = []

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    init_w = sess.run(W)
    init_b = sess.run(b)
    
    ax1.plot(x,-init_w[0]/init_w[1]*x+init_b,label='init',c='gray')
    
    w_list.append([init_w[0][0],init_w[1][0]])
    b_list.append(init_b[0])
    
    for step in range(epoch):
        
        _,weight,bias, cost_val,acc_val = sess.run([train_op,W,b, error, accuracy], 
                                       feed_dict={X: train_X, Y: train_Y.reshape(len(train_Y),1)})
        
        print("step: ",step,"\tw1, w2: ",weight[0],weight[1],"\tb: ",bias,"\terror: ", cost_val,"\tacc: ",acc_val)
        
        w_list.append([weight[0][0],weight[1][0]])
        b_list.append(bias[0])
        error_list.append(cost_val)
        acc_list.append(acc_val)
        
        
    ax1.plot(x,-w_list[-1][0]/w_list[-1][1]*x+bias[-1],label='f`',c='black')
    
    
    # 최적화가 완료된 모델에 테스트 값을 넣고 결과가 잘 나오는지 확인해봅니다.
#     print("\n=== Test ===")
#     print("X:, ",test)
#     print("Y:", sess.run(f, feed_dict={X: test}))
# Out:
# step:  0 	w1, w2:  [-4.17848015] [-4.57974958] 	b:  [-0.06999999] 	error:  1.59873 	acc:  0.49
# step:  1 	w1, w2:  [-3.6926012] [-4.16243076] 	b:  [ 0.17999998] 	error:  3.95895 	acc:  0.75
# step:  2 	w1, w2:  [-3.20672226] [-3.74511194] 	b:  [ 0.42999995] 	error:  3.48622 	acc:  0.75
# step:  3 	w1, w2:  [-2.7139926] [-3.33410549] 	b:  [ 0.67499995] 	error:  3.01396 	acc:  0.755
	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  250 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  251 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  252 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  253 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  254 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  255 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  256 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  257 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  258 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  259 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  260 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  261 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  262 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  263 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  264 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  265 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  266 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  267 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  268 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  269 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  270 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  271 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  272 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  273 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  274 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  275 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  276 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  277 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  278 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  279 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  280 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  281 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  282 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  283 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  284 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  285 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  286 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  287 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  288 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  289 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  290 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  291 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  292 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  293 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  294 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  295 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  296 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  297 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  298 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  299 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  300 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  301 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  302 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  303 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  304 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  305 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  306 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  307 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  308 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  309 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  310 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  311 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  312 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  313 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  314 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  315 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  316 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  317 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  318 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  319 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  320 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  321 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  322 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  323 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  324 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  325 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  326 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  327 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  328 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  329 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  330 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  331 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  332 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  333 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  334 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  335 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  336 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  337 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  338 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  339 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  340 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  341 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  342 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  343 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  344 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  345 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  346 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  347 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  348 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  349 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  350 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  351 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  352 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  353 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  354 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  355 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  356 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  357 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  358 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  359 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  360 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  361 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  362 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  363 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  364 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  365 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  366 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  367 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  368 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  369 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  370 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  371 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  372 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  373 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  374 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  375 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  376 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  377 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  378 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  379 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  380 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  381 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  382 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  383 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  384 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  385 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  386 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  387 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  388 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  389 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  390 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  391 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  392 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  393 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  394 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  395 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  396 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  397 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  398 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0
# step:  399 	w1, w2:  [-0.08879796] [-0.17589125] 	b:  [ 2.00999999] 	error:  0.0 	acc:  1.0

# %% [markdown]
# ### graph3 error 변화

# %%
ax3.set_xlim(0,epoch)
ax3.set_xlabel("step")
ax3.set_ylabel("error")

step = np.linspace(0,epoch,epoch)
ax3.plot(step,error_list)

# %% [markdown]
# ### graph4 accuracy 변화

# %%
ax4.set_xlim(0,epoch)
ax4.set_xlabel("step")
ax4.set_ylabel("accuracy")

step = np.linspace(0,epoch,epoch)
ax4.plot(step,acc_list)

# %% [markdown]
# ### error surface

# %%
ax2 = fig.add_subplot(322, projection='3d')
ax2.set_xlabel("w1")
ax2.set_ylabel("w2")
ax2.set_zlabel("error")
w1, w2 = np.meshgrid(np.array(w_list)[1:,0], np.array(w_list)[1:,1])
ax2.plot_wireframe(w1, w2, error_list,label='gradient surface')
ax2.plot(np.array(w_list)[1:,0], np.array(w_list)[1:,1],error_list,c='red',label='gradient')
ax2.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3,
           ncol=2, mode="expand", borderaxespad=0.)

# %% [markdown]
# ### graph1 f\` 변화

# %%
def init(w,b):
    line.set_ydata(-w[0][0]/w[0][1]*x+b[0])
    ax1.set_title('Frame ' + str('0'))
    return line,

def animate(i,w,b):
    line.set_ydata(-w[i][0]/w[i][1]*x+b[i])
    ax1.set_title('Step ' + str(i))
    return line,

# %%
line, = ax1.plot(x,-w_list[0][1]/w_list[1][0]*x + b_list[0],label='f` being learned ')
ax1.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=3,
           ncol=2, mode="expand", borderaxespad=0.)
ani = animation.FuncAnimation(fig,animate,np.arange(0,epoch),interval=1,blit=True,fargs=(w_list,b_list,))
